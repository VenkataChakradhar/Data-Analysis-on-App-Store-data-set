# %% [markdown]
# # Data Cleanig

# %%
import pandas as pd

# %%
appstore_games =pd.read_excel(r'D:\Mini_Project\appstore_games data.xlsx', sheet_name ='Sheet1')

# %%
appstore_games
# Out:
#                                                      URL          ID  \
# 0       https://apps.apple.com/us/app/sudoku/id284921427   284921427
# 1      https://apps.apple.com/us/app/reversi/id284926400   284926400
# 2      https://apps.apple.com/us/app/morocco/id284946595   284946595
# 3      https://apps.apple.com/us/app/sudoku-free/id28...   285755462
# 4      https://apps.apple.com/us/app/senet-deluxe/id2...   285831220
# ...                                                  ...         ...
# 17002  https://apps.apple.com/us/app/stack-puzzle-ris...  1474626442
# 17003  https://apps.apple.com/us/app/eachother/id1474...  1474919257
# 17004  https://apps.apple.com/us/app/rabbit-vs-tortoi...  1474962324
# 17005  https://apps.apple.com/us/app/fatall/id1474963671  1474963671
# 17006  https://apps.apple.com/us/app/the-three-kingdo...  1475076711
#
#                             Name                        Subtitle  \
# 0                         Sudoku                             NaN
# ...

# %% [markdown]
# # Dropping description,id,url,icon url,subtitle columns

# %%
appstore_games.drop(['Description','URL','ID','Subtitle','Icon URL'], axis=1, inplace=True)

# %%
appstore_games
# Out:
#                             Name  Average User Rating  User Rating Count  \
# 0                         Sudoku                  4.0             3553.0
# 1                        Reversi                  3.5              284.0
# 2                        Morocco                  3.0             8376.0
# 3                  Sudoku (Free)                  3.5           190394.0
# 4                   Senet Deluxe                  3.5               28.0
# ...                          ...                  ...                ...
# 17002  Stack Puzzle : Rise Tower                  NaN                NaN
# 17003                  EachOther                  NaN                NaN
# 17004         Rabbit Vs Tortoise                  NaN                NaN
# 17005                     FaTaLL                  NaN                NaN
# 17006   The Three Kingdoms :Bomb                  NaN                NaN
#
#        Price   In-app Purchases                 Developer Age Rating  \
# ...

# %% [markdown]
# # Games without User Rating should be dropped.

# %%
appstore_games.dropna(subset =["User Rating Count"],how="any",inplace=True)

# %%
appstore_games
# Out:
#                         Name  Average User Rating  User Rating Count  Price  \
# 0                     Sudoku                  4.0             3553.0   2.99
# 1                    Reversi                  3.5              284.0   1.99
# 2                    Morocco                  3.0             8376.0   0.00
# 3              Sudoku (Free)                  3.5           190394.0   0.00
# 4               Senet Deluxe                  3.5               28.0   2.99
# ...                      ...                  ...                ...    ...
# 16950               Die Last                  3.0                6.0   0.00
# 16956            Basic Slosh                  5.0               30.0   0.00
# 16962     Idle Racing Tycoon                  5.0               51.0   0.00
# 16967     Glow Hockey Strike                  5.0                5.0   0.00
# 16993  Agadmator Chess Clock                  5.0               33.0   0.00
#
# ...

# %%
appstore_games.shape
# Out:
# (7561, 13)

# %%
appstore_games.isnull().sum()
# Out:
# Name                               0
# Average User Rating                0
# User Rating Count                  0
# Price                              0
# In-app Purchases                2927
# Developer                          0
# Age Rating                         0
# Languages                         24
# Size                               0
# Primary Genre                      0
# Genres                             0
# Original Release Date              0
# Current Version Release Date       0
# dtype: int64

# %% [markdown]
# # Perform Data Preparation by cleaning the data and removing null values.

# %%
appstore_games.dropna(how="any",inplace=True)

# %%
appstore_games.isnull().sum()
# Out:
# Name                            0
# Average User Rating             0
# User Rating Count               0
# Price                           0
# In-app Purchases                0
# Developer                       0
# Age Rating                      0
# Languages                       0
# Size                            0
# Primary Genre                   0
# Genres                          0
# Original Release Date           0
# Current Version Release Date    0
# dtype: int64

# %%
nan_value = float("NaN")

appstore_games.replace(" ", nan_value, inplace=True)

# %%
appstore_games.dropna(how="any",inplace=True)

# %%
appstore_games
# Out:
#                                  Name  Average User Rating  User Rating Count  \
# 5      Sudoku - Classic number puzzle                  3.0               47.0
# 15           Awele/Oware - Mancala HD                  3.0              112.0
# 16           Awele/Oware - Mancala HD                  3.0              112.0
# 18                       Catcha Mouse                  3.5            95971.0
# 19        Cool Sudoku, Jigsaw, Killer                  3.5              357.0
# ...                               ...                  ...                ...
# 16828                  Zipline Valley                  4.5               14.0
# 16842              Lordz2.io Conquest                  3.0               17.0
# 16856             Smartphone Tycoon 2                  2.5               29.0
# 16863      Hero Chess: Teamfight Auto                  4.5               51.0
# 16932        Spatula: TFT Cheat Sheet                  5.0               11.0
#
# ...

# %%
appstore_games.isnull().sum()
# Out:
# Name                            0
# Average User Rating             0
# User Rating Count               0
# Price                           0
# In-app Purchases                0
# Developer                       0
# Age Rating                      0
# Languages                       0
# Size                            0
# Primary Genre                   0
# Genres                          0
# Original Release Date           0
# Current Version Release Date    0
# dtype: int64

# %%
appstore_games.shape
# Out:
# (4618, 13)

# %% [markdown]
# # Games with less than 200 user rating AND days since last update date <6month has been dropped

# %%
appstore_games.drop(appstore_games[(appstore_games['Current Version Release Date'] < '01-07-2019') | (appstore_games['User Rating Count'] < 200)].index,inplace = True)

# %%
appstore_games
# Out:
#                                Name  Average User Rating  User Rating Count  \
# 19      Cool Sudoku, Jigsaw, Killer                  3.5              357.0
# 70                             Slay                  3.0             4885.0
# 90     UniWar: Multiplayer Strategy                  3.5            14073.0
# 118                           Chess                  4.5            14864.0
# 127           Pixel Starships\u2122                  4.5            27739.0
# ...                             ...                  ...                ...
# 16629             Auto Chess:Origin                  4.5             2943.0
# 16647              Super Chef World                  4.5              256.0
# 16694              Smash Brickz Pro                  4.5              354.0
# 16718               Car Wash Empire                  5.0              658.0
# 16729                       OG West                  5.0              267.0
#
# ...

# %%
appstore_games.Genres.unique().shape
# Out:
# (141,)

# %% [markdown]
# # Genre tags "Entertainment" and "Games" are removed from the Genre string as it does not provide meaningful insight

# %%
temp = appstore_games.Genres.str.replace('Games','')

# %%
temp
# Out:
# 19             , Strategy, Puzzle, Entertainment
# 70                             , Board, Strategy
# 90       , Entertainment, Strategy, Role Playing
# 118             , Strategy, Board, Entertainment
# 127      , Entertainment, Strategy, Role Playing
#                           ...
# 16629                                 , Strategy
# 16647      , Simulation, Entertainment, Strategy
# 16694                         , Strategy, Puzzle
# 16718          , Strategy, Puzzle, Entertainment
# 16729      , Entertainment, Simulation, Strategy
# Name: Genres, Length: 810, dtype: object

# %%
temp1=temp.str.replace('Strategy','')

# %%
temp1
# Out:
# 19             , , Puzzle, Entertainment
# 70                             , Board,
# 90       , Entertainment, , Role Playing
# 118             , , Board, Entertainment
# 127      , Entertainment, , Role Playing
#                       ...
# 16629                                 ,
# 16647      , Simulation, Entertainment,
# 16694                         , , Puzzle
# 16718          , , Puzzle, Entertainment
# 16729      , Entertainment, Simulation,
# Name: Genres, Length: 810, dtype: object

# %%
temp2=temp1.str.replace('Entertainment','')

# %%
temp2
# Out:
# 19             , , Puzzle,
# 70                , Board,
# 90       , , , Role Playing
# 118             , , Board,
# 127      , , , Role Playing
#                 ...
# 16629                    ,
# 16647      , Simulation, ,
# 16694            , , Puzzle
# 16718          , , Puzzle,
# 16729      , , Simulation,
# Name: Genres, Length: 810, dtype: object

# %%
temp3=temp2.str.replace(',','')

# %%
appstore_games.Genres=temp3

# %%
appstore_games['Genres'] = appstore_games['Genres'].str.strip()

# %%
appstore_games.drop(appstore_games[appstore_games['Genres'] == ''].index, inplace = True)

# %%
appstore_games
# Out:
#                                  Name  Average User Rating  User Rating Count  \
# 19        Cool Sudoku, Jigsaw, Killer                  3.5              357.0
# 70                               Slay                  3.0             4885.0
# 90       UniWar: Multiplayer Strategy                  3.5            14073.0
# 118                             Chess                  4.5            14864.0
# 127             Pixel Starships\u2122                  4.5            27739.0
# ...                               ...                  ...                ...
# 16596  Jewel Adventure - Match 3 Game                  4.5              475.0
# 16647                Super Chef World                  4.5              256.0
# 16694                Smash Brickz Pro                  4.5              354.0
# 16718                 Car Wash Empire                  5.0              658.0
# 16729                         OG West                  5.0              267.0
#
# ...

# %% [markdown]
# # The remaining of the string are checked and grouped as follows:
# 1.Puzzle= Puzzle/Board
# 2.Adventure= Adventure/Role/Role Playing
# 3.Action = Action
# 4.Family = Family/Education

# %%
puzzle=['Puzzle','Board']
Puzzle=appstore_games.loc[appstore_games['Genres'].isin(puzzle)]

# %%
Puzzle
# Out:
#                                  Name  Average User Rating  User Rating Count  \
# 19        Cool Sudoku, Jigsaw, Killer                  3.5              357.0
# 70                               Slay                  3.0             4885.0
# 118                             Chess                  4.5            14864.0
# 156              Chess - Play & Learn                  4.5           143719.0
# 180                     Catan Classic                  4.0            17440.0
# ...                               ...                  ...                ...
# 16269    Toy Crush Block Puzzle Games                  5.0              615.0
# 16475   Jewel Castle - Matching Games                  4.5              704.0
# 16596  Jewel Adventure - Match 3 Game                  4.5              475.0
# 16694                Smash Brickz Pro                  4.5              354.0
# 16718                 Car Wash Empire                  5.0              658.0
#
# ...

# %%
adventure=['Adventure','Role', 'Role Playing']
Adventure=appstore_games.loc[appstore_games['Genres'].isin(adventure)]

# %%
Adventure
# Out:
#                                Name  Average User Rating  User Rating Count  \
# 90     UniWar: Multiplayer Strategy                  3.5            14073.0
# 127           Pixel Starships\u2122                  4.5            27739.0
# 507                   Empire Online                  4.5            15468.0
# 597              Sea Jurassic Craft                  4.5             3548.0
# 663                      Crime City                  4.0            51485.0
# ...                             ...                  ...                ...
# 16171    Idle Convoy VS Zombies Inc                  4.5              329.0
# 16213       LightSlinger Heroes RPG                  4.5              246.0
# 16257    Mighty Quest For Epic Loot                  4.5            17984.0
# 16278     Mobile Legends: Adventure                  5.0             2478.0
# 16307          Rise of Heroes - RoH                  4.5              460.0
#
# ...

# %%
action=['Action']
Action=appstore_games.loc[appstore_games['Genres'].isin(action)]

# %%
Action
# Out:
#                                  Name  Average User Rating  User Rating Count  \
# 819      Majesty: Fantasy Kingdom Sim                  4.5              988.0
# 1039                  Kingdom Rush HD                  5.0            36212.0
# 1195   Super Tank Battle - myCityArmy                  4.0              387.0
# 1238                  Radiant Defense                  4.0              981.0
# 1254                "Papa's Burgeria"                  4.5             1659.0
# ...                               ...                  ...                ...
# 15023   World War 2 - Online Strategy                  4.5              285.0
# 15061          Retract: Battle Royale                  3.5              345.0
# 15276                    Game of Gods                  4.5             1045.0
# 15593     Age of Sail: Navy & Pirates                  4.5              321.0
# 15638             Heroic - Magic Duel                  4.5              969.0
#
# ...

# %%
family=['Family','Education']
Family=appstore_games.loc[appstore_games['Genres'].isin(family)]

# %%
Family
# Out:
#                                       Name  Average User Rating  \
# 1450               Knights & Dragons - RPG                  4.5
# 2092                         Lunch Rush HD                  4.5
# 2378          Delicious - Honeymoon Cruise                  4.5
# 2617                       Cookie Clickers                  4.5
# 2786         Delicious Honeymoon Cruise HD                  4.5
# 2864         Toilet Time: Crazy Mini Games                  4.5
# 4281                         Cow Evolution                  5.0
# 5166           City Island 3: Building Sim                  4.5
# 5995        Rabbit Evolution Merge in Farm                  5.0
# 7776                   Asterix and Friends                  4.5
# 13353                     Evolution Galaxy                  4.5
# 13946       Crazy Cooking: Food Craze Game                  4.5
# 14616        Cats & Cosplay: Tower Defense                  5.0
# 14725  Hell\u2019s Cooking - madness fever                  4.5
# ...

# %% [markdown]
# # Stating inferences of every Genres of its
#   1.Average User Rating
#   2.Price
#   3.Size
#   4.User Rating Count

# %%
Puzzle.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001D4DD7C1B48>,
# ...
#       dtype=object)

# %%
Adventure.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001D4DA3D8B48>,
# ...
#       dtype=object)

# %%
Action.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001D4E1B503C8>,
# ...
#       dtype=object)

# %%
Family.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001D4DFFF51C8>,
# ...
#       dtype=object)

# %% [markdown]
# # Identifying which genres have higher user ratings.

# %%
appstore_games[appstore_games['Average User Rating'] > 4.0].Genres.unique()
# Out:
# array(['Board', 'Role Playing', 'Puzzle', 'Card', 'Simulation',
#        'Board  Education', 'Finance  Simulation', 'Action', 'Family',
#        'Puzzle Education', 'Finance Simulation', 'Adventure',
#        'Simulation  Social Networking', 'Casual', 'Trivia', 'Utilities',
#        'Role Playing Social Networking', 'Card  Travel',
#        'Social Networking Role Playing', 'Board  Sports', 'Sports Sports',
#        'Sports  Card', 'Action Sports', 'Music', 'Casino',
#        'Sports  Sports', 'Simulation Education', 'Racing',
#        'Health & Fitness   Role Playing', 'Action Books',
#        'Simulation  Business', 'Business Board', 'Sports',
#        'Finance   Simulation', 'Card Social Networking',
#        'Education Family', 'Education Simulation', 'Simulation  Music',
#        'Sports Card', 'Role Playing Lifestyle', 'Education  Simulation',
#        'Role Playing Education', 'Lifestyle  Trivia',
#        'Lifestyle Simulation', 'Social Networking  Adventure',
# ...

# %% [markdown]
# # Data Visualization

# %%
high=appstore_games[appstore_games['Average User Rating'] > 4.0]
high
# Out:
#                                  Name  Average User Rating  User Rating Count  \
# 118                             Chess                  4.5            14864.0
# 127             Pixel Starships\u2122                  4.5            27739.0
# 156              Chess - Play & Learn                  4.5           143719.0
# 343                          Aqueduct                  4.5             1312.0
# 348                       \u25bbCHESS                  4.5            22149.0
# ...                               ...                  ...                ...
# 16596  Jewel Adventure - Match 3 Game                  4.5              475.0
# 16647                Super Chef World                  4.5              256.0
# 16694                Smash Brickz Pro                  4.5              354.0
# 16718                 Car Wash Empire                  5.0              658.0
# 16729                         OG West                  5.0              267.0
#
# ...

# %%
high.groupby(['Genres','Average User Rating']).size().unstack().plot(kind='barh',figsize=(10,20),stacked=True)
plt.show()
